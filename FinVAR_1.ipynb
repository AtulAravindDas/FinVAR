# %% [markdown]
# <a href="https://colab.research.google.com/github/AtulAravindDas/FinVAR/blob/FinVAR-Atul/FinVAR_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance

# %%
import yfinance as yf

# %%
user_input=input('Enter a stock ticker symbol: ')
ticker=yf.Ticker(user_input)
ticker_income_statement=ticker.financials
ticker_balance_sheet=ticker.balance_sheet
ticker_cash_flow=ticker.cashflow
ticker_income_statement
# Out:
# Enter a stock ticker symbol: DELL
#                                                        2025-01-31  \
# Tax Effect Of Unusual Items                             6110000.0
# Tax Rate For Calcs                                          0.094
# Normalized EBITDA                                    9520000000.0
# Total Unusual Items                                    65000000.0
# Total Unusual Items Excluding Goodwill                 65000000.0
# Net Income From Continuing Operation Net Minori...   4592000000.0
# Reconciled Depreciation                              3123000000.0
# Reconciled Cost Of Revenue                          74317000000.0
# EBITDA                                               9585000000.0
# EBIT                                                 6462000000.0
# Net Interest Income                                 -1254000000.0
# Interest Expense                                     1414000000.0
# Interest Income                                       160000000.0
# ...

# %%
ticker_balance_sheet
# Out:
#                                                      2025-01-31  \
# Treasury Shares Number                              138000000.0
# Ordinary Shares Number                              696130464.0
# Share Issued                                        834130464.0
# Net Debt                                          20934000000.0
# Total Debt                                        24567000000.0
# ...                                                         ...
# Accounts Receivable                               10298000000.0
# Allowance For Doubtful Accounts Receivable          -63000000.0
# Gross Accounts Receivable                         10361000000.0
# Cash Cash Equivalents And Short Term Investments   3633000000.0
# Cash And Cash Equivalents                          3633000000.0
#
#                                                      2024-01-31  \
# Treasury Shares Number                              116000000.0
# Ordinary Shares Number                              706335200.0
# ...

# %%
ticker_cash_flow
# Out:
#                                                    2025-01-31     2024-01-31  \
# Free Cash Flow                                   1869000000.0   5920000000.0
# Repurchase Of Capital Stock                     -3165000000.0  -2452000000.0
# Repayment Of Debt                              -10570000000.0 -11246000000.0
# Issuance Of Debt                                 9258000000.0   7775000000.0
# Issuance Of Capital Stock                           1000000.0     10000000.0
# Capital Expenditure                             -2652000000.0  -2756000000.0
# Interest Paid Supplemental Data                  1304000000.0   1438000000.0
# Income Tax Paid Supplemental Data                 555000000.0   1379000000.0
# End Cash Position                                3819000000.0   7507000000.0
# Beginning Cash Position                          7507000000.0   8894000000.0
# Effect Of Exchange Rate Changes                  -179000000.0   -186000000.0
# ...
