# %% [markdown]
# <a href="https://colab.research.google.com/github/AtulAravindDas/FinVAR/blob/main/Datasetcreation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Cleaning the EPS dataset(obtained it from Compustat Fundamental Annual page)**

# %%
df=pd.read_csv('/content/drive/MyDrive/ticker_eps.csv')

# %%
df
# Out:
#       datadate  fyear datafmt  tic  epspx
# 0     12/31/15   2015     STD  ABT   1.73
# 1     12/31/16   2016     STD  ABT   0.71
# 2     12/31/17   2017     STD  ABT   0.20
# 3     12/31/18   2018     STD  ABT   1.32
# 4     12/31/19   2019     STD  ABT   2.07
# ...        ...    ...     ...  ...    ...
# 2279  12/31/20   2020     STD  LYB   4.25
# 2280  12/31/21   2021     STD  LYB  16.79
# 2281  12/31/22   2022     STD  LYB  11.86
# 2282  12/31/23   2023     STD  LYB   6.50
# 2283  12/31/24   2024     STD  LYB   4.15
#
# [2284 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# datadate      0
# fyear         0
# datafmt       0
# tic           0
# epspx       275
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# datadate    0
# fyear       0
# datafmt     0
# tic         0
# epspx       0
# dtype: int64

# %%
new_df=df
new_df
# Out:
#       datadate  fyear datafmt  tic  epspx
# 0     12/31/15   2015     STD  ABT   1.73
# 1     12/31/16   2016     STD  ABT   0.71
# 2     12/31/17   2017     STD  ABT   0.20
# 3     12/31/18   2018     STD  ABT   1.32
# 4     12/31/19   2019     STD  ABT   2.07
# ...        ...    ...     ...  ...    ...
# 2279  12/31/20   2020     STD  LYB   4.25
# 2280  12/31/21   2021     STD  LYB  16.79
# 2281  12/31/22   2022     STD  LYB  11.86
# 2282  12/31/23   2023     STD  LYB   6.50
# 2283  12/31/24   2024     STD  LYB   4.15
#
# [2009 rows x 5 columns]

# %%
new_df.to_csv('updated_ticker_eps.csv',index=False)

# %% [markdown]
# # **Cleaning the Financial Ratios Dataset(obtained using Compustat Financial Ratios)**

# %%
financial_ratios=pd.read_csv('/content/drive/MyDrive/Financial_Ratios.csv')
financial_ratios.head()
# Out:
#    permno       adate       qdate public_date  pe_exi    npm  opmad    roa  \
# 0   10104  2014-05-31  2014-11-30  2015-01-31  17.454  0.281  0.391  0.199
# 1   10104  2014-05-31  2014-11-30  2015-02-28  18.258  0.281  0.391  0.199
# 2   10104  2014-05-31  2014-11-30  2015-03-31  17.979  0.281  0.391  0.199
# 3   10104  2014-05-31  2015-02-28  2015-04-30  18.251  0.279  0.386  0.190
# 4   10104  2014-05-31  2015-02-28  2015-05-31  18.197  0.279  0.386  0.190
#
#      roe  de_ratio  intcov_ratio  curr_ratio TICKER
# 0  0.238     0.999        14.982       3.837   ORCL
# 1  0.238     0.999        14.982       3.837   ORCL
# 2  0.238     0.999        14.982       3.837   ORCL
# 3  0.232     1.029        14.180       3.916   ORCL
# 4  0.232     1.029        14.180       3.916   ORCL

# %%
financial_ratios.drop(columns=['adate','qdate'],axis=1,inplace=True)

# %%
financial_ratios.isnull().sum()
# Out:
# permno             0
# public_date        0
# pe_exi           217
# npm               21
# opmad             21
# roa               33
# roe             1097
# de_ratio           9
# intcov_ratio    1928
# curr_ratio      3143
# TICKER             5
# dtype: int64

# %%
null_values_ticker_count = financial_ratios[financial_ratios['TICKER'].isnull()]
null_values_ticker_count
# Out:
#       permno public_date   pe_exi    npm  opmad    roa    roe  de_ratio  \
# 3840   15408  2015-09-30      NaN  0.043  0.221  0.072  0.023     1.373
# 3841   15408  2015-10-31      NaN  0.043  0.221  0.072  0.023     1.373
# 4290   16692  2017-07-31 -127.560 -0.017  0.100  0.086 -0.045    14.689
# 5940   20057  2021-01-31   32.673  0.023  0.168  0.118  0.020     1.588
# 6828   22623  2022-04-30      NaN    NaN    NaN    NaN    NaN       NaN
#
#       intcov_ratio  curr_ratio TICKER
# 3840         2.497       1.755    NaN
# 3841         2.497       1.755    NaN
# 4290         1.151       2.417    NaN
# 5940         4.129       1.084    NaN
# 6828           NaN         NaN    NaN

# %%
financial_ratios[financial_ratios['permno']==15408]['TICKER'].unique()
# Out:
# array([nan, 'KHC'], dtype=object)

# %%
# Replace null values in 'TICKER' column for permno 15408 with 'KHC'
financial_ratios.loc[(financial_ratios['permno'] == 15408) & (financial_ratios['TICKER'].isnull()), 'TICKER'] = 'KHC'

# %%
financial_ratios.isnull().sum()
# Out:
# permno             0
# public_date        0
# pe_exi           217
# npm               21
# opmad             21
# roa               33
# roe             1097
# de_ratio           9
# intcov_ratio    1928
# curr_ratio      3143
# TICKER             3
# dtype: int64

# %%
null_values_ticker_count = financial_ratios[financial_ratios['TICKER'].isnull()]
null_values_ticker_count
# Out:
#       permno public_date   pe_exi    npm  opmad    roa    roe  de_ratio  \
# 4290   16692  2017-07-31 -127.560 -0.017  0.100  0.086 -0.045    14.689
# 5940   20057  2021-01-31   32.673  0.023  0.168  0.118  0.020     1.588
# 6828   22623  2022-04-30      NaN    NaN    NaN    NaN    NaN       NaN
#
#       intcov_ratio  curr_ratio TICKER
# 4290         1.151       2.417    NaN
# 5940         4.129       1.084    NaN
# 6828           NaN         NaN    NaN

# %%
financial_ratios[financial_ratios['permno']==16692]
financial_ratios[financial_ratios['permno']==16692]['TICKER'].unique()
# Out:
# array([nan, 'GDI', 'IR'], dtype=object)

# %%
financial_ratios[financial_ratios['permno']==20057]['TICKER'].unique()
# Out:
# array([nan, 'VTRS'], dtype=object)

# %%
financial_ratios[financial_ratios['permno']==22623]['TICKER'].unique()
# Out:
# array([nan, 'CEG'], dtype=object)

# %%
# prompt: Replace all the null values in the ticker column having the permno 15408 with KHC in financial_ratios

# Replace null values in 'TICKER' column for permno 15408 with 'KHC'
financial_ratios.loc[(financial_ratios['permno'] == 22623) & (financial_ratios['TICKER'].isnull()), 'TICKER'] = 'CEG'
financial_ratios.loc[(financial_ratios['permno'] == 20057) & (financial_ratios['TICKER'].isnull()), 'TICKER'] = 'VTRS'

# %%
null_values_ticker_count=financial_ratios[financial_ratios['TICKER'].isnull()]
null_values_ticker_count
# Out:
#       permno public_date  pe_exi    npm  opmad    roa    roe  de_ratio  \
# 4290   16692  2017-07-31 -127.56 -0.017    0.1  0.086 -0.045    14.689
#
#       intcov_ratio  curr_ratio TICKER
# 4290         1.151       2.417    NaN

# %%
financial_ratios[financial_ratios['permno']==16692]
# Out:
#       permno public_date   pe_exi    npm  opmad    roa    roe  de_ratio  \
# 4290   16692  2017-07-31 -127.560 -0.017  0.100  0.086 -0.045    14.689
# 4291   16692  2017-08-31  -25.258 -0.084  0.034  0.057 -0.232     6.418
# 4292   16692  2017-09-30  -29.591 -0.084  0.034  0.057 -0.232     6.418
# 4293   16692  2017-10-31  -31.022 -0.084  0.034  0.057 -0.232     6.418
# 4294   16692  2017-11-30  -46.300 -0.059  0.064  0.074 -0.129     4.807
# ...      ...         ...      ...    ...    ...    ...    ...       ...
# 4375   16692  2024-08-31   45.272  0.117  0.194  0.120  0.080     0.630
# 4376   16692  2024-09-30   48.594  0.117  0.194  0.120  0.080     0.630
# 4377   16692  2024-10-31   47.525  0.117  0.194  0.120  0.080     0.630
# 4378   16692  2024-11-30   50.815  0.117  0.199  0.118  0.080     0.678
# 4379   16692  2024-12-31   44.127  0.117  0.199  0.118  0.080     0.678
#
#       intcov_ratio  curr_ratio TICKER
# 4290         1.151       2.417    NaN
# ...

# %%
financial_ratios.loc[(financial_ratios['permno'] == 16692) & (financial_ratios['TICKER'].isnull()), 'TICKER'] = 'GDI'

# %%
null_values_ticker_count=financial_ratios[financial_ratios['TICKER'].isnull()]
null_values_ticker_count
# Out:
# Empty DataFrame
# Columns: [permno, public_date, pe_exi, npm, opmad, roa, roe, de_ratio, intcov_ratio, curr_ratio, TICKER]
# Index: []

# %%
null_value_count=financial_ratios.isnull().sum()
null_value_count
# Out:
# permno             0
# public_date        0
# pe_exi           217
# npm               21
# opmad             21
# roa               33
# roe             1097
# de_ratio           9
# intcov_ratio    1928
# curr_ratio      3143
# TICKER             0
# dtype: int64

# %%
df
# Out:
#       datadate  fyear datafmt  tic  epspx
# 0     12/31/15   2015     STD  ABT   1.73
# 1     12/31/16   2016     STD  ABT   0.71
# 2     12/31/17   2017     STD  ABT   0.20
# 3     12/31/18   2018     STD  ABT   1.32
# 4     12/31/19   2019     STD  ABT   2.07
# ...        ...    ...     ...  ...    ...
# 2279  12/31/20   2020     STD  LYB   4.25
# 2280  12/31/21   2021     STD  LYB  16.79
# 2281  12/31/22   2022     STD  LYB  11.86
# 2282  12/31/23   2023     STD  LYB   6.50
# 2283  12/31/24   2024     STD  LYB   4.15
#
# [2009 rows x 5 columns]

# %%
import pandas as pd
financial_ratios['year'] = pd.to_datetime(financial_ratios['public_date']).dt.year

# %%
financial_ratios.head()
# Out:
#    permno public_date  pe_exi    npm  opmad    roa    roe  de_ratio  \
# 0   10104  2015-01-31  17.454  0.281  0.391  0.199  0.238     0.999
# 1   10104  2015-02-28  18.258  0.281  0.391  0.199  0.238     0.999
# 2   10104  2015-03-31  17.979  0.281  0.391  0.199  0.238     0.999
# 3   10104  2015-04-30  18.251  0.279  0.386  0.190  0.232     1.029
# 4   10104  2015-05-31  18.197  0.279  0.386  0.190  0.232     1.029
#
#    intcov_ratio  curr_ratio TICKER  year
# 0        14.982       3.837   ORCL  2015
# 1        14.982       3.837   ORCL  2015
# 2        14.982       3.837   ORCL  2015
# 3        14.180       3.916   ORCL  2015
# 4        14.180       3.916   ORCL  2015

# %%
new_df.head()
# Out:
#    datadate  fyear datafmt  tic  epspx
# 0  12/31/15   2015     STD  ABT   1.73
# 1  12/31/16   2016     STD  ABT   0.71
# 2  12/31/17   2017     STD  ABT   0.20
# 3  12/31/18   2018     STD  ABT   1.32
# 4  12/31/19   2019     STD  ABT   2.07

# %%
new_df.columns.tolist()
# Out:
# ['datadate', 'fyear', 'datafmt', 'tic', 'epspx']

# %%
new_df = new_df.rename(columns={'tic': 'TICKER'})

# %%
import numpy as np

financial_ratios['epspx'] = np.nan


for index, row in financial_ratios.iterrows():
    ticker = row['TICKER']
    year = row['year']

    matching_rows = new_df[(new_df['TICKER'] == ticker) & (new_df['fyear'] == year)]

    if not matching_rows.empty:
        financial_ratios.loc[index, 'epspx'] = matching_rows['epspx'].iloc[0]

# %%
financial_ratios.head()
# Out:
#    permno public_date  pe_exi    npm  opmad    roa    roe  de_ratio  \
# 0   10104  2015-01-31  17.454  0.281  0.391  0.199  0.238     0.999
# 1   10104  2015-02-28  18.258  0.281  0.391  0.199  0.238     0.999
# 2   10104  2015-03-31  17.979  0.281  0.391  0.199  0.238     0.999
# 3   10104  2015-04-30  18.251  0.279  0.386  0.190  0.232     1.029
# 4   10104  2015-05-31  18.197  0.279  0.386  0.190  0.232     1.029
#
#    intcov_ratio  curr_ratio TICKER  year  epspx
# 0        14.982       3.837   ORCL  2015   2.11
# 1        14.982       3.837   ORCL  2015   2.11
# 2        14.982       3.837   ORCL  2015   2.11
# 3        14.180       3.916   ORCL  2015   2.11
# 4        14.180       3.916   ORCL  2015   2.11

# %%
financial_ratios.isnull().sum()
# Out:
# permno             0
# public_date        0
# pe_exi           217
# npm               21
# opmad             21
# roa               33
# roe             1097
# de_ratio           9
# intcov_ratio    1928
# curr_ratio      3143
# TICKER             0
# year               0
# epspx           1233
# dtype: int64

# %%
null_ticker_list=financial_ratios[financial_ratios['epspx'].isnull()]['TICKER'].unique()

# %%
for ticker in null_ticker_list:
  print(ticker)
  print(financial_ratios[financial_ratios['TICKER']==ticker])
# Out:
# ORCL
#      permno public_date  pe_exi    npm  opmad    roa    roe  de_ratio  \
# 0     10104  2015-01-31  17.454  0.281  0.391  0.199  0.238     0.999
# 1     10104  2015-02-28  18.258  0.281  0.391  0.199  0.238     0.999
# 2     10104  2015-03-31  17.979  0.281  0.391  0.199  0.238     0.999
# 3     10104  2015-04-30  18.251  0.279  0.386  0.190  0.232     1.029
# 4     10104  2015-05-31  18.197  0.279  0.386  0.190  0.232     1.029
# ..      ...         ...     ...    ...    ...    ...    ...       ...
# 115   10104  2024-08-31  38.084  0.198  0.297  0.159  0.821    15.135
# 116   10104  2024-09-30  45.930  0.198  0.297  0.159  0.821    15.135
# 117   10104  2024-10-31  43.258  0.204  0.304  0.164  1.118    18.116
# 118   10104  2024-11-30  47.639  0.204  0.304  0.164  1.118    18.116
# 119   10104  2024-12-31  42.948  0.204  0.304  0.164  1.118    18.116
#
#      intcov_ratio  curr_ratio TICKER  year  epspx
# 0          14.982       3.837   ORCL  2015   2.11
# ...

# %%
financial_ratios.isnull().sum()
# Out:
# permno             0
# public_date        0
# pe_exi           217
# npm               21
# opmad             21
# roa               33
# roe             1097
# de_ratio           9
# intcov_ratio    1928
# curr_ratio      3143
# TICKER             0
# year               0
# epspx           1233
# dtype: int64

# %%
missing_percent = financial_ratios.isnull().mean() * 100
print(missing_percent.sort_values(ascending=False))
# Out:
# curr_ratio      13.720697
# intcov_ratio     8.416641
# epspx            5.382634
# roe              4.788929
# pe_exi           0.947309
# roa              0.144061
# opmad            0.091675
# npm              0.091675
# de_ratio         0.039289
# public_date      0.000000
# permno           0.000000
# TICKER           0.000000
# year             0.000000
# dtype: float64

# %%
null_cols = ['curr_ratio', 'intcov_ratio', 'epspx', 'roe', 'pe_exi', 'roa', 'opmad', 'npm', 'de_ratio']
for col in null_cols:
  financial_ratios[col].fillna(financial_ratios[col].median(), inplace=True)
# Out:
# <ipython-input-42-3d3a2e1e3d9a>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   financial_ratios[col].fillna(financial_ratios[col].median(), inplace=True)

# %% [markdown]
# ## **Adding the revenues of the companies based on Ticker Names and Years and also generating the final dataframe to be used for Analysis**

# %%
revenues_df=pd.read_csv('/content/drive/MyDrive/company_revenues.csv')
revenues_df.head()
# Out:
#    gvkey    datadate  fyear indfmt consol popsrc datafmt  tic curcd     revt  \
# 0   1078  2015-12-31   2015   INDL      C      D     STD  ABT   USD  20405.0
# 1   1078  2016-12-31   2016   INDL      C      D     STD  ABT   USD  20853.0
# 2   1078  2017-12-31   2017   INDL      C      D     STD  ABT   USD  27390.0
# 3   1078  2018-12-31   2018   INDL      C      D     STD  ABT   USD  30578.0
# 4   1078  2019-12-31   2019   INDL      C      D     STD  ABT   USD  31904.0
#
#   costat
# 0      A
# 1      A
# 2      A
# 3      A
# 4      A

# %%
revenues_df.rename(columns={'tic':'TICKER','fyear':'year'},inplace=True)

# %%
revenues_df.head()
# Out:
#    gvkey    datadate  year indfmt consol popsrc datafmt TICKER curcd     revt  \
# 0   1078  2015-12-31  2015   INDL      C      D     STD    ABT   USD  20405.0
# 1   1078  2016-12-31  2016   INDL      C      D     STD    ABT   USD  20853.0
# 2   1078  2017-12-31  2017   INDL      C      D     STD    ABT   USD  27390.0
# 3   1078  2018-12-31  2018   INDL      C      D     STD    ABT   USD  30578.0
# 4   1078  2019-12-31  2019   INDL      C      D     STD    ABT   USD  31904.0
#
#   costat
# 0      A
# 1      A
# 2      A
# 3      A
# 4      A

# %%
revenues_df.drop(columns=['datadate','gvkey','indfmt','consol','popsrc','datafmt','curcd','costat'],axis=1,inplace=True)
revenues_df.head()
# Out:
#    year TICKER     revt
# 0  2015    ABT  20405.0
# 1  2016    ABT  20853.0
# 2  2017    ABT  27390.0
# 3  2018    ABT  30578.0
# 4  2019    ABT  31904.0

# %%
financial_ratios.head()
# Out:
#    permno public_date  pe_exi    npm  opmad    roa    roe  de_ratio  \
# 0   10104  2015-01-31  17.454  0.281  0.391  0.199  0.238     0.999
# 1   10104  2015-02-28  18.258  0.281  0.391  0.199  0.238     0.999
# 2   10104  2015-03-31  17.979  0.281  0.391  0.199  0.238     0.999
# 3   10104  2015-04-30  18.251  0.279  0.386  0.190  0.232     1.029
# 4   10104  2015-05-31  18.197  0.279  0.386  0.190  0.232     1.029
#
#    intcov_ratio  curr_ratio TICKER  year  epspx
# 0        14.982       3.837   ORCL  2015   2.11
# 1        14.982       3.837   ORCL  2015   2.11
# 2        14.982       3.837   ORCL  2015   2.11
# 3        14.180       3.916   ORCL  2015   2.11
# 4        14.180       3.916   ORCL  2015   2.11

# %%
financial_ratios=financial_ratios.merge(revenues_df[['TICKER','year','revt']],on=['TICKER','year'],how='left')
financial_ratios.head()
# Out:
#    permno public_date  pe_exi    npm  opmad    roa    roe  de_ratio  \
# 0   10104  2015-01-31  17.454  0.281  0.391  0.199  0.238     0.999
# 1   10104  2015-02-28  18.258  0.281  0.391  0.199  0.238     0.999
# 2   10104  2015-03-31  17.979  0.281  0.391  0.199  0.238     0.999
# 3   10104  2015-04-30  18.251  0.279  0.386  0.190  0.232     1.029
# 4   10104  2015-05-31  18.197  0.279  0.386  0.190  0.232     1.029
#
#    intcov_ratio  curr_ratio TICKER  year  epspx     revt
# 0        14.982       3.837   ORCL  2015   2.11  37047.0
# 1        14.982       3.837   ORCL  2015   2.11  37047.0
# 2        14.982       3.837   ORCL  2015   2.11  37047.0
# 3        14.180       3.916   ORCL  2015   2.11  37047.0
# 4        14.180       3.916   ORCL  2015   2.11  37047.0

# %%
epspx=financial_ratios['epspx']
epspx
# Out:
# 0        2.11
# 1        2.11
# 2        2.11
# 3        2.11
# 4        2.11
#          ...
# 26303    2.23
# 26304    2.23
# 26305    2.23
# 26306    2.23
# 26307    2.23
# Name: epspx, Length: 26308, dtype: float64

# %%
financial_ratios.drop(columns=['epspx'],axis=1,inplace=True)
financial_ratios['EPS']=epspx
financial_ratios.head()
# Out:
#    permno public_date  pe_exi    npm  opmad    roa    roe  de_ratio  \
# 0   10104  2015-01-31  17.454  0.281  0.391  0.199  0.238     0.999
# 1   10104  2015-02-28  18.258  0.281  0.391  0.199  0.238     0.999
# 2   10104  2015-03-31  17.979  0.281  0.391  0.199  0.238     0.999
# 3   10104  2015-04-30  18.251  0.279  0.386  0.190  0.232     1.029
# 4   10104  2015-05-31  18.197  0.279  0.386  0.190  0.232     1.029
#
#    intcov_ratio  curr_ratio TICKER  year     revt   EPS
# 0        14.982       3.837   ORCL  2015  37047.0  2.11
# 1        14.982       3.837   ORCL  2015  37047.0  2.11
# 2        14.982       3.837   ORCL  2015  37047.0  2.11
# 3        14.180       3.916   ORCL  2015  37047.0  2.11
# 4        14.180       3.916   ORCL  2015  37047.0  2.11

# %%
financial_ratios.isnull().sum()
# Out:
# permno             0
# public_date        0
# pe_exi             0
# npm                0
# opmad              0
# roa                0
# roe                0
# de_ratio           0
# intcov_ratio       0
# curr_ratio         0
# TICKER             0
# year               0
# revt            1233
# EPS                0
# dtype: int64

# %%
col='revt'
financial_ratios[col].fillna(financial_ratios[col].median(), inplace=True)
financial_ratios.isnull().sum()
# Out:
# <ipython-input-64-978bdf8a85ce>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   financial_ratios[col].fillna(financial_ratios[col].median(), inplace=True)
# permno          0
# public_date     0
# pe_exi          0
# npm             0
# opmad           0
# roa             0
# roe             0
# de_ratio        0
# intcov_ratio    0
# curr_ratio      0
# TICKER          0
# year            0
# revt            0
# EPS             0
# dtype: int64

# %%
financial_ratios.rename(columns={'revt':'Revenue'},inplace=True)

# %%
financial_ratios.to_csv('Financial_ratios_with_eps_and_revenue.csv')
